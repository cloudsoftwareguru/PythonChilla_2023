# %% [markdown]
# Exploratory Data Analysis is a method used to analyse and summarize datasets.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset("titanic")
# print(df.head())
# print(df.tail())
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.isnull

# %%
df.isnull().sum() * 100 /len(df)

# %%
df.nunique()

# %%
df.columns

# %%
sns.heatmap(df.isnull(), yticklabels=True, cbar=True, cmap='viridis')

# %%
df.drop(columns="deck", inplace=True)

# %%
df.shape
# Out:
# (891, 14)

# %%
#visualize and explore
sns.countplot(data=df, x="survived")
# Out:
# <AxesSubplot: xlabel='survived', ylabel='count'>

# %%
sns.barplot(data=df, x="survived", y="age", hue="who")
# Out:
# <AxesSubplot: xlabel='survived', ylabel='age'>

# %%
sns.barplot(data=df, x="survived", y="fare", hue="who")
# Out:
# <AxesSubplot: xlabel='survived', ylabel='fare'>

# %%
sns.countplot(x="pclass", data=df)
# Out:
# <AxesSubplot: xlabel='pclass', ylabel='count'>

# %%
sns.pairplot(df, hue='survived')

# %%
#stacked barchart/plot

df.groupby(['pclass', 'sex'])

# %%
# sns.lmplot(data=df, x='age', y=df[df.fare])
sns.lmplot(data=df, x='age', y='fare')

# %%
# df.groupby("age_groups")["survived"].mean().plot(kind="bar")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male  embark_town alive  alone
# ...

# %%
#make a new filtered df that has rows with fare less than 100
df_filtered = df[df['fare']<300]
sns.lmplot(data=df_filtered, x='age', y='fare')
# plt.ylim(0,300)

# %%
#make a new filtered df that has rows with fare less than $300
sns.lmplot(data=df[df['fare']<100], x='age', y='fare', hue='who')
